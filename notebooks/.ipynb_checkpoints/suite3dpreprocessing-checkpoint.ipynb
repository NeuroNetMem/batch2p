# %%
## import stuff
from datetime import date
from matplotlib import pyplot as plt
import numpy as np
import os
import tifffile as tiff
import glob as glob
from pathlib import Path

# we need to set the current path to the directory
# containing the suite3d repository, this hack should
# do the trick
os.chdir(os.path.dirname(os.path.abspath("")))

from suite3d.job import Job
from suite3d import io
from suite3d import plot_utils as plot
# Out:
# /Users/fpbattaglia/src/suite3d/suite3d/io/tiff_utils.py:85: SyntaxWarning: invalid escape sequence '\d'
#   return float(re.findall("\d+\.\d+", tag)[0])

# %%
# define path to data
#path = Path("/mnt/imaging1/imaging1/Veronique/2p_datasets/OFL/477116/20251118") # this is actually path to multiday data not 3d data
path = Path("/Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test")

# Check if it exists
if path.exists():
    print("Path exists!")
else:
    print("Path does not exist.")

# get tif files
tifs = io.get_tif_paths(path)
for tif in tifs: print(tif)
# Out:
# Path exists!
# /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test/477116_20251118_00001_0_6000.tif

# %%
print(io.get_vol_rate(tifs[0]))
# Out:
# 29.96393939393939

# %%
# Set the mandatory parameters
# for now some parameters are just guesses
params = {
    # volume rate
    'fs': io.get_vol_rate(tifs[0]),

    # planes to analyze (we have 3 planes)
    'planes' : np.array([0,1,2]),
    # number of planes recorded
    'n_ch_tif' : 3,

    # Decay time of the Ca indicator in seconds. 1.3 for GCaMP6s. This example is for GCamP8m
    'tau' : 1.3,
    'lbm' : False,
    'num_colors' : 1, # how many color channels were recorded by scanimage
    'functional_color_channel' : 0, # which color channel is the functional one
     # voxel size in z,y,x in microns
    'voxel_size_um' : (30, 0.84, 0.84),
    # number of files to use for the initial pass
    # usually, ~500 frames is a good rule of thumb
    # we will just use 200 here for speed
    'n_init_files' :  1,  # more of those makes it crash due to mem issues
    "init_n_frames": 500,

    # 3D GPU registration - fast!
    '3d_reg' : True,
    'gpu_reg' : True,

    # note : 3D CPU is not supported yet
    'subtract_crosstalk' : False, # turn off some lbm-only features
    'fuse_strips' : False, # turn off some lbm-only features
    "cell_filt_xy_um": 8,


    "split_tif_size": 100,
    "peak_thresh": 0.5,
    "extend_thresh": 0.005,
    #"activity_thresh": 8.0,
    #"percentile": 90.0,
    #"extend_thresh": 0.1,
    #"max_pix": 1000,




}

# %%
### Create the job
job = Job(r'/Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test','xy_1000', tifs = tifs,
          params=params, create=True, overwrite=True, verbosity = 3)
job.params.update(params)
# Out:
# Job directory /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test/s3d-xy_1000 already exists
# Loading job directory for xy_1000 in /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test
#    Loading dirs
#       Found dir registered_fused_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param fs
#       Updating param planes
#       Updating param n_ch_tif
#       Updating param tau
#       Updating param lbm
#       Updating param num_colors
#       Updating param functional_color_channel
#       Updating param voxel_size_um
#       Updating param n_init_files
#       Updating param init_n_frames
#       Updating param 3d_reg
#       Updating param gpu_reg
#       Updating param subtract_crosstalk
#       Updating param fuse_strips
#       Updating param cell_filt_xy_um
#       Updating param split_tif_size
#       Updating param peak_thresh
#       Updating param extend_thresh
#    Updated main params file

# %%
job.run_init_pass()
# Out:
#    Saved a copy of params at /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test/s3d-xy_1000/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test/s3d-xy_1000/summary/summary.npy
#    Loading init tifs with 3 channels
#       Loading tiff 1/1: /Users/fpbattaglia/Dropbox/Data/ofl_2p/00001_test/477116_20251118_00001_0_6000.tif
#    Loaded 1 files, total 2.93 GB
#    Selecting 500 random frames from the init tif files
#    Loaded movie with 500 frames and shape 3, 512, 512
#       Enforcing positivity in mean image
#    No crosstalk estimation or subtraction
#    Using 3d registration
#    Computing plane alignment shifts
#    Applying plane alignment shifts
#    Launching 3D GPU reference image calculation
#       Seeding reference image with most active frames
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 job.run_init_pass()
#
# File ~/src/suite3d/suite3d/job.py:482, in Job.run_init_pass(self)
#     480 self.save_params(copy_dir_tag="summary")
#     481 self.log("Launching initial pass", 0)
# --> 482 run_init_pass(self)
#
# File ~/src/suite3d/suite3d/init_pass.py:225, in run_init_pass(job)
#     215 if reference_params["3d_reg"]:
#     216     job.log("Using 3d registration")
#     217     (
#     218         tvecs,
#     219         ref_image,
#     220         all_refs_and_masks,
#     221         pad_sizes,
#     222         reference_params,
#     223         reference_info,
#     224         shifted_mov,
# --> 225     ) = ref.compute_reference_and_masks_3d(
#     226         mov_fuse,
#     227         reference_params,
#     228         log_cb=job.log,
#     229         use_GPU=params.get("gpu_reg", True),
#     230     )
#     232     summary_mov_path = os.path.join(job.dirs["summary"], "init_mov.npy")
#     233     n.save(summary_mov_path, shifted_mov)
#
# File ~/src/suite3d/suite3d/reference_image.py:1281, in compute_reference_and_masks_3d(mov_cpu, reference_params, log_cb, rmins, rmaxs, use_GPU)
#    1278 if use_GPU:
#    1279     log_cb("Launching 3D GPU reference image calculation", 1)
#    1280     ref_img, zmax, ymax, xmax, cmax, used_frames, subpix_shifts, shifted_mov = (
# -> 1281         get_reference_img_gpu_3d(
#    1282             mov_cpu,
#    1283             percent_contribute,
#    1284             niter,
#    1285             xpad,
#    1286             ypad,
#    1287             rmins=rmins,
#    1288             rmaxs=rmaxs,
#    1289             batch_size=batch_size,
#    1290             pc_size=pc_size,
#    1291             sigma=sigma,
#    1292             log_cb=log_cb,
#    1293         )
#    1294     )
#    1295 else:
#    1296     log_cb("Launching 3D CPU reference image calculation", 1)
#
# File ~/src/suite3d/suite3d/reference_image.py:1435, in get_reference_img_gpu_3d(mov_cpu, percent_contribute, niter, xpad, ypad, rmins, rmaxs, batch_size, pc_size, sigma, log_cb)
#    1430     add_mask = compute_mask_offset(ref_img, mult_mask)
#    1432 refs_f = reg_3d.mask_filter_fft_ref(ref_img, mult_mask, add_mask, smooth=0.5)
#    1434 phase_corr_shifted, int_shift, pc_peak_loc, subpix_shift, __ = (
# -> 1435     reg_3d.rigid_3d_ref_gpu(
#    1436         mov_cropped,
#    1437         mult_mask,
#    1438         add_mask,
#    1439         refs_f,
#    1440         pc_size,
#    1441         batch_size=batch_size,
#    1442         rmins=None,
#    1443         rmaxs=None,
#    1444         crosstalk_coeff=None,
#    1445     )
#    1446 )
#    1447 pc_peak_loc = pc_peak_loc.astype(np.int32)
#    1448 int_shift = int_shift.astype(np.int32)
#
# File ~/src/suite3d/suite3d/reg_3d.py:583, in rigid_3d_ref_gpu(mov_cpu, mult_mask, add_mask, refs_f, pc_size, batch_size, rmins, rmaxs, crosstalk_coeff, shift_reg, xpad, ypad, fuse_shift, new_xs, old_xs, plane_shifts, process_mov, cavity_size)
#     549 """
#     550 Runs rigid registration on the gpu.
#     551
#    (...)    580     The sub pixel shift estiamted from the phase correlation
#     581 """
#     582 if not HAS_CUPY:
# --> 583     raise ImportError(
#     584         "GPU registration requires cupy. Please install cupy to use this function."
#     585         " See https://docs.cupy.dev/en/stable/install.html for installation instructions."
#     586     )
#     587 mempool = cp.get_default_memory_pool()
#     588 __, nt, __, __ = mov_cpu.shape
#
# ImportError: GPU registration requires cupy. Please install cupy to use this function. See https://docs.cupy.dev/en/stable/install.html for installation instructions.

# %%
# If you have large tiffs, split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 100

# %%
# OPTIONAL: load and take a look at the reference image
summary = job.load_summary()
ref_img = summary['ref_img_3d']

# # view 1 plane at a time
plot.show_img(ref_img[0], figsize=(3,4))
plot.show_img(ref_img[1], figsize=(3,4))
plot.show_img(ref_img[2], figsize=(3,4))

# # interactive 3D viewer
# plot.VolumeViewer(ref_img)

# %%
job.register()

# %%
corr_map = job.calculate_corr_map()

# %%
res = job.load_corr_map_results()
vmap = res['vmap']

# %%
plot.show_img(ref_img[0], figsize=(3,4))
plot.show_img(res['max_img'][0], figsize=(3,4))

plot.show_img(ref_img[1], figsize=(3,4))
plot.show_img(res['max_img'][1], figsize=(3,4))

plot.show_img(ref_img[2], figsize=(3,4))
plot.show_img(res['mean_img'][2], figsize=(3,4))

# %%
job.params['patch_size_xy'] = (1000, 1000)
# for speed, only segment a single patch
job.segment_rois()

# %%
job.compute_npil_masks()
traces = job.extract_and_deconvolve()

# %%
job.export_results('/home/user/Desktop/Veronique/test_francesco/s3d-xy_1000/',result_dir_name='rois')
